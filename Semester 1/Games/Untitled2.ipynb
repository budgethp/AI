# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_json("games.json")

# %%
sns.scatterplot(x='price', y='recommendations', data=df)
df['log_negative'] =np.log(df['negative'])
df['log_positive'] =np.log(df['positive'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.scatterplot(x='log_positive', y='log_negative', data = df)
# Out:
# <AxesSubplot:xlabel='log_positive', ylabel='log_negative'>

# %%
def histogram_intersection(a, b):
    v = np.minimum(a, b).sum().round(decimals=1)
    return v

# %%
df.corr(method="pearson")
# Out:
#                                 ID  peak_ccu  required_age     price  \
# ID                        1.000000 -0.008097     -0.103954 -0.066164
# peak_ccu                 -0.008097  1.000000      0.028416  0.040309
# required_age             -0.103954  0.028416      1.000000  0.094271
# price                    -0.066164  0.040309      0.094271  1.000000
# dlc_count                      NaN       NaN           NaN       NaN
# windows                   0.007552  0.000384     -0.006858 -0.015266
# mac                      -0.201905  0.002614     -0.002783  0.033587
# linux                    -0.139542  0.003509      0.001357  0.026972
# metacritic_score         -0.263051  0.038814      0.195588  0.135616
# user_score               -0.018262 -0.000429      0.079026 -0.000489
# positive                 -0.046919  0.469666      0.067499  0.029094
# negative                 -0.038944  0.397728      0.065021  0.024773
# score_rank                0.152725 -0.254030      0.079917  0.281748
# ...

# %%
subDF = df[['positive', 'negative']]

# %%
subDF.corr(method="pearson")
# Out:
#           positive  negative
# positive  1.000000  0.782384
# negative  0.782384  1.000000

# %%
sub2DF = df[['positive', 'average_playtime_2weeks']]
df['playtime2weekslog'] =np.log(df['average_playtime_2weeks'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sub2DF.corr(method="pearson")
# Out:
#                          positive  average_playtime_2weeks
# positive                 1.000000                 0.103005
# average_playtime_2weeks  0.103005                 1.000000

# %%
sns.scatterplot(x='log_positive', y='playtime2weekslog', data = df)
# Out:
# <AxesSubplot:xlabel='log_positive', ylabel='playtime2weekslog'>

# %%
sns.scatterplot(x='positive', y='recommendations', data = df)
# Out:
# <AxesSubplot:xlabel='positive', ylabel='recommendations'>

# %%
sub3DF = df[['positive', 'recom']]
