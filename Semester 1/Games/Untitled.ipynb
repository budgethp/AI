# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_json("games.json")

# %%
for idx in range(len(df)):
    if df["ID"][idx] == 22380:
        print(df.loc[idx])
        break
# Out:
# ID                                                                      22380
# name                                                       Fallout: New Vegas
# release_date                                                     Oct 19, 2010
# estimated_owners                                            2000000 - 5000000
# peak_ccu                                                                 5776
# required_age                                                               16
# price                                                                    9.99
# dlc_count                                                                   0
# main_description            Welcome to Vegas. New Vegas. It’s the kind of ...
# supported_languages         ['English', 'French', 'German', 'Italian', 'Sp...
# full_audio_languages                                                       []
# reviews                                                                  None
# ...

# %%
filtered_df = df[df['name'].fillna('').str.contains('Call of Duty', case=False)]
print(filtered_df)
# Out:
#             ID                                              name  \
# 136       7940                  Call of Duty® 4: Modern Warfare®
# 3073     42710                          Call of Duty®: Black Ops
# 7629    393080         Call of Duty®: Modern Warfare® Remastered
# 8176    202990                       Call of Duty®: Black Ops II
# 15118   311210                      Call of Duty®: Black Ops III
# 16436   209160                             Call of Duty®: Ghosts
# 20805     2640                    Call of Duty: United Offensive
# 21930   209650    Call of Duty®: Advanced Warfare - Gold Edition
# 22085   209660    Call of Duty®: Advanced Warfare - Gold Edition
# 24094   476600                               Call of Duty®: WWII
# 27498    10090                        Call of Duty: World at War
# 29125    42680                  Call of Duty®: Modern Warfare® 3
# 29670    42700                          Call of Duty®: Black Ops
# ...

# %%
print(len(filtered_df))
# Out:
# 35

# %%
print(df[df['name'].fillna('').str.contains('V.A', case=False)])
# Out:
#             ID                                               name  \
# 1019    781760                 Trivia Vault: Health Trivia Deluxe
# 1249   1547990                                     Vivian's Kurse
# 1352   1173120                                         Markov Alg
# 1600    716920                      The Ultimate Trivia Challenge
# 1702    844140                        Trivia Vault: Soccer Trivia
# ...        ...                                                ...
# 95871  3094770                                     LoveAndComplex
# 96122  2986400                                Roundscape Adorevia
# 96176  3049610  Synaxarion Christian Stories: Holy Martyr Savv...
# 96557  1316680                                      VLADiK BRUTAL
# 96829  2873620                      Rasvyat Nuclear Power Station
#
#        release_date estimated_owners  peak_ccu  required_age  price  \
# 1019   Jan 23, 2018        0 - 20000         0             0   1.49
# ...

# %%
sns.scatterplot(x='price', y='positive', data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='positive'>
