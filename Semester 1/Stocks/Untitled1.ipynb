# %%
import pandas as pd
import seaborn as sns
import numpy as np
df = pd.read_json("tsla.json", encoding = 'ISO-8859-1')

# %%
print(df.columns)
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'rsi_7', 'rsi_14',
#        'cci_7', 'cci_14', 'sma_50', 'ema_50', 'sma_100', 'ema_100', 'macd',
#        'bollinger', 'TrueRange', 'atr_7', 'atr_14', 'next_day_close'],
#       dtype='object')

# %%
sub2DF = df[['open', 'close']]

sns.scatterplot(x='open', y='close', data=df)
sub2DF.corr(method="pearson")
# Out:
#            open     close
# open   1.000000  0.999081
# close  0.999081  1.000000
