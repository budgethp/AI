# %%
import pandas as pd
import seaborn as sns
totalcount = 0
df = pd.read_csv("spotify2023.csv", encoding='ISO-8859-1')
df['streams'] = pd.to_numeric(df['streams'], errors = 'coerce')
sns.boxplot(x=df['danceability_%'])
print(df['danceability_%'].mean())
# Out:
# 66.96956977964324
